# %% [markdown]
# **Scrapping Aplikasi PT Vidio Dot Com**
#
# Vidio adalah platform OTT (Over the Top) penyedia layanan streaming terlengkap di Indonesia, yang berdiri sejak tahun 2014.
#
# Kelebihan Vidio sebagai platform streaming terlengkap di Indonesia:
#
# * Sports terlengkap ada di Vidio: Nikmati tayangan olahraga terpopuler seperti Premier League, BRI Liga 1, UEFA Champions League, UEFA Europa League, Seria, La Liga, NBA, Indonesian Basketball League (IBL),Voli Proliga, Tenis WTA dan masih banyak lagi
#
# * Vidio Original Series #YangPalingIndonesia dengan berbagai macam jenis genre dari mulai drama, komedi, hingga action. Semua konten ini di perankan oleh artis-artis terbaik di Indonesia
#
# * Vidio Games di konten-konten favorit. Gampang mainnya, gampang menang banyak

# %% [markdown]
# Requirements:
#
# *   google-play-scraper-1.2.7
# *   sastrawi-1.0.1
# *   pandas 2.0.3

# %%
# !pip list

# %%
# !pip install google-play-scraper

# %%
# !pip install sastrawi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort, reviews_all

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews_all, Sort

# Mengambil semua ulasan dari aplikasi dengan ID 'com.byu.id' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
scrapreview = reviews_all(
    'com.vidio.android',          # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=1000             # Jumlah maksimum ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
import csv
import pandas as pd

app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi_vidio.csv', index=False)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  28be6724-6ea4-40ef-8f49-2a899231b8e3  Pengguna Google
# 1  d77c731b-ea2d-432c-87cf-0b7ab90113e7  Pengguna Google
# 2  c34cdf0f-f324-48c0-a553-46a337120fba  Pengguna Google
# 3  1ef053af-9562-4aaf-a2ba-c1ef341eb646  Pengguna Google
# 4  3494802d-6b4e-4e44-8115-c70b4eb9ca54  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Nonton muter muter aja padahal udah berlanggan...      2             62
# 1  Kecewa, sudah langganan bertahun-tahun, tidak ...      1            247
# ...
